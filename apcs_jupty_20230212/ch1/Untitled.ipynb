# %%
print("Hello")
print(123)
print(1.41421)
print(3.1415,2.71828)
print(4,5,6,sep="-",end="\n\n")
print("Python!!")
print("Ken\nVivin")
# Out:
# Hello
# 123
# 1.41421
# 3.1415 2.71828
# 4-5-6
#
# Python!!
# Ken
# Vivin

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
age1 = 18
print(age1)
age2 = 1.56
print(age2)
# Out:
# 18
# 1.56

# %%
salary = 25000
commission = 1000
sales = 18
pay = salary + commission * sales

print("銷售量:",sales)
print("薪資:",pay,"元")
# Out:
# 銷售量: 18
# 薪資: 43000 元

# %%
price = 250
print(price)

price = 199
print(price)

price = 150.99
print(price)

del price
print(price)
# Out:
# 250
# 199
# 150.99
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16872\2107705502.py in <module>
#       9
#      10 del price
# ---> 11 print(price)
#
# NameError: name 'price' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
coin = 0
print("coin:",coin)
coin += 1
print("coin:",coin)
coin += 2
print("coin:",coin)

value1 = 8

v2 = value1 / 3
print(v2)
v3 = value1 // 3 #求商數 無條件捨去
print(v3)
print("========================")
#注意餘數規律
v4 = 0 % 3#一定是0~2之間的數
print(v4)
v4 = 1 % 3#一定是0~2之間的數
print(v4)
v4 = 2 % 3#一定是0~2之間的數
print(v4)
v4 = 3 % 3#一定是0~2之間的數
print(v4)
v4 = 4 % 3#一定是0~2之間的數
print(v4)
v4 = 5 % 3#一定是0~2之間的數
print(v4)
v4 = 6 % 3#一定是0~2之間的數
print(v4)
v4 = 7 % 3#一定是0~2之間的數
print(v4)
print("==========n次方==============")
print(2**3)#2的3次方 2 * 2 * 2
print(3**2)#3的2次方 3 * 3
# Out:
# coin: 0
# coin: 1
# coin: 3
# 2.6666666666666665
# 2
# ========================
# 0
# 1
# 2
# 0
# 1
# 2
# 0
# 1
# ==========n次方==============
# 8
# 9

# %%
num = 10

num += 9#num = num + 9
print(num)
num -= 8# num = num - 8
print(num)
num *= 7
print(num)
num //= 6
print(num)
num %= 5 # num = num % 5
print(num)
num /= 4
print(num)
num **= 3 # num = num ** 3
print(num)
# Out:
# 19
# 11
# 77
# 12
# 2
# 0.5
# 0.125

# %%
coin1 = 20
coin5 = 10
coin10 = 3
coin50 = 2
coin_total = coin50 * 50  + coin10 * 10 + coin5 * 5 + coin1
print("金幣總額:",coin_total)
b100 = 3
b200 = 2
b500 = 1
b1000 = 2
b_total = (b100 + b200 * 2 + b500 * 5 + b1000 * 10)  * 100
print("紙鈔金額:",b_total)

print("總額:",b_total + coin_total)
# Out:
# 金幣總額: 200
# 紙鈔金額: 3200
# 總額: 3400

# %%
x = 9 + 3 * 2 ** 2 -1
print(x)
# Out:
# 20

# %% [markdown]
# # 作業
# ![image.png](attachment:image.png)
