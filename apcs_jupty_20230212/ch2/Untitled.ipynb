# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
title = '先生'
lastName = "邱"
greet = '你好'
print(lastName+title+greet)

thank = "感謝"
very = "非常"
print(very*3+thank)
# Out:
# 邱先生你好
# 非常非常非常感謝

# %%
myid = 245536

myStr = "我的ID:" + str(myid)
print(myStr)

myStrId = "34567"
newId = int(myStrId) + 1
print(newId)
# Out:
# 我的ID:245536
# 34568

# %%
a = 3
b = 4
print(a,b)
tmp = a
a = b
b = tmp
print(a,b)


c = 25
g = 16
c,g = g,c
print(c,g)
# Out:
# 3 4
# 4 3
# 16 25

# %%
myid = 245536

myStr = "我的ID:" + str(myid)
print(myStr)

myStrId = "34567"
newId = int(myStrId) + 1
print(newId)
# Out:
# 我的ID:245536
# 34568

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
h = input("請輸入身高:")
print(h)
print(type(h))

w = int(input("請輸入體重:"))
print(w)
print(type(w))
# Out:
# 請輸入身高:180
# 180
# <class 'str'>
# 請輸入體重:72
# 72
# <class 'int'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tc = int(input('輸入攝氏溫度:'))

tf = 9/5*tc+32

print('攝氏', tc, '度等於華氏', tf, '度')
# Out:
# 輸入攝氏溫度:25
# 攝氏 25 度等於華氏 77.0 度

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
height = float(input("請輸入身高cm:"))
weight = int(input("請輸入體重kg:"))
bmi = weight / ((height / 100) ** 2)
print("bmi為:",bmi)
# Out:
# 請輸入身高cm:180
# 請輸入體重kg:72
# bmi為: 22.22222222222222

# %%
name = "小明"
age = 12
print(name,"今年",age,"歲",sep="")

print("%s今年%d歲"%(name,age))
# Out:
# 小明今年12歲
# 小明今年12歲

# %%
print("value:%.2f"%12.2367)

value = 15
print("abc%5dgef"%value)
print("abc%-5dgef"%value)
h = 2
m = 7
s = 15
print("Time:%02d"%s)
print("%02d:%02d:%02d"%(h,m,s))
#02:07:05
# Out:
# value:12.24
# abc   15gef
# abc15   gef
# Time:15
# 02:07:15

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
h = float(input("請輸入身高cm:"))
w = int(input("請輸入體重kg:"))
bmi = w /((h /100)**2)
print("bmi:%.2f"%bmi)
print(f"bmi是:{bmi:.2f}")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#1024B = 1kB
#1024KB = 1mB
#1024MB = 1GB
#1024GB = 1TG

var1 = 123 # 32bit 4byte 1kb 1mb 1gb
print(type(var1))
var2 = 3.14 #32bit  4byte
print(type(var2))
var3 = True
print(type(var3))
var4 = 'Hello'
print(type(var4))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'str'>

# %%
x,y = 5,0
print(x,bool(x))
print(y,bool(y))

x,y = 1.5,0.0
print(x,bool(x))
print(y,bool(y))

x = "Hi"
y = ""
print(x,bool(x))
print(y,bool(y))

x = [1,2,3]
y = []
print(x,bool(x))
print(x,bool(y))
# Out:
# 5 True
# 0 False
# 1.5 True
# 0.0 False
# Hi True
#  False
# [1, 2, 3] True
# [1, 2, 3] False

# %%
str1 ="這是我的\"關鍵\"字"
print(str1)
str2 = "斷行1\n斷行2"
print(str2)
str3 = "Tab1\tTab2"
print(str3)
#\\ 就是輸出\
path = "c:\python\\net"
print(path)
path2 = r"c:\python\net"
print(path2)
# Out:
# 這是我的"關鍵"字
# 斷行1
# 斷行2
# Tab1	Tab2
# c:\python\net
# c:\python\net

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 123
print(id(x))
x = 456
print(id(x))
x = "Hello"
print(id(x))
y = "Hello"
print(id(y))
# Out:
# 140729529613024
# 1918279632208
# 1918279414064
# 1918279414064

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 10
print(x)
print(type(x))

y = x + 5.5

print(y)
print(type(y))
print(type(x))
# Out:
# 10
# <class 'int'>
# 15.5
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
str1 ="這是我的\"關鍵\"字"
print(str1)
str2 = "斷行1\n斷行2"
print(str2)
str3 = "Tab1\tTab2"
print(str3)
#\\ 就是輸出\
path = "c:\python\\net"
print(path)
path2 = r"c:\python\net"
print(path2)
# Out:
# 這是我的"關鍵"字
# 斷行1
# 斷行2
# Tab1	Tab2
# c:\python\net
# c:\python\net

# %%
mystring1 = "Hello World"
print(mystring1)
print(mystring1[2])
print(mystring1[-2])
print(mystring1[2:])
print(mystring1[:3])
print(mystring1[1:4])

print(mystring1[-4:-1])
print(mystring1[::-1])
# Out:
# Hello World
# l
# l
# llo World
# Hel
# ell
# orl
# dlroW olleH

# %%
str1 = '我是"關鍵"字' #字串內容有雙引號就使用單引包字串
str2 = "你好'Ken'" #字串內容有單引號就使用雙引包字串
print(str1)
print(str2)

myHtml = '''<html>
<head>
        <style>
            a:link{
              color:brown;      
            }
        </style>        
    </head>
<body>    
    <a href="#">AAA</a>
</body>
</html>'''
print(myHtml)
# Out:
# 我是"關鍵"字
# 你好'Ken'
# <html>
# <head>
#         <style>
#             a:link{
#               color:brown;
#             }
#         </style>
#     </head>
# <body>
#     <a href="#">AAA</a>
# </body>
# </html>

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
v1 = input("請輸入字串:")

if v1 == v1[::-1]:
    print(v1,"是迴文")
else:
    print(v1,"不是迴文")
# Out:
# 請輸入字串:aba
# aba 是迴文

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pid = input('輸入身分證字號')
gender = int(pid[1])
if gender == 1:
    print("先生您好")
else:
    print("小姐您好")
# Out:
# 輸入身分證字號A1234567
# 先生您好

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
list1 = ['H','i']
tuple1 = ('H','i')

print(tuple1)
print(list1)

list1[1] = 'a'

print(list1)
#tuple1[1] = 'a'
# Out:
# ('H', 'i')
# ['H', 'i']
# ['H', 'a']

# %%
#immutable
str1 = "HelloWorld"
print(str1[1])
str1[1] = 8
str1 = "Test" #給str1一個新的數值
print(str1)
# Out:
# e
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21128\270591751.py in <module>
#       2 str1 = "HelloWorld"
#       3 print(str1[1])
# ----> 4 str1[1] = 8
#       5 str1 = "Test" #給str1一個新的數值
#       6 print(str1)
#
# TypeError: 'str' object does not support item assignment

# %%
scores = [60,70,75,90,100]
print(scores)
scores[2] = 80
print(scores)
del scores[2]
print(scores)
del scores[1:3]
print(scores)
del scores
print(scores)
# Out:
# [60, 70, 75, 90, 100]
# [60, 70, 80, 90, 100]
# [60, 70, 90, 100]
# [60, 100]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21128\127999356.py in <module>
#       8 print(scores)
#       9 del scores
# ---> 10 print(scores)
#
# NameError: name 'scores' is not defined

# %%
list1 = ['H','e','l','l','o','W','o','r','l','d']
print(list1[0])
print(list1[1])
print(list1[-1])
print(list1[-3])

print(list1[2:])
print(list1[:-3])
print(list1[3:5])
# Out:
# H
# e
# d
# r
# ['l', 'l', 'o', 'W', 'o', 'r', 'l', 'd']
# ['H', 'e', 'l', 'l', 'o', 'W', 'o']
# ['l', 'o']
